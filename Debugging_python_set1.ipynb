# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
def add_numbers(a, b):
    return a + b
add_numbers(5,4)
# Out:
# 9

# %%
numbers = [1, 2, 3, 4,5]
print(numbers[4])
# Out:
# 5

# %%
print ("Hello, World!")
# Out:
# Hello, World!

# %%
x = 5 / 5
print(x)
# Out:
# 1.0

# %%
name=str("Alice")
age = 25
print("Name: " + name + ", Age: " + str(age))
# Out:
# Name: Alice, Age: 25

# %%
for i in range(1, 10, 1):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
x = 10
if (x == 5):
    print("x is 5")

# %%
def greet(name):
    print("Hello, " + name)
greet(name)
# Out:
# Hello, Alice
